# %%
import numpy as np
import matplotlib.pyplot as plt
data_path = '/home/mabon/Pico_Clean/Pico_Scope_Data_Clean/V2/200k_fpga/fpga_200k.npz'
whole_pack = np.load(data_path)

trace_array, textin_array= whole_pack['power_trace'], whole_pack['plain_text']

# %%
# Create a list of colors for each array
colors = [ 'g', 'r', 'c', 'm', 'y', 'k', 'w', '#FFA500', '#800080','b']
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(np.arange(0, 701, 100))
plt.xlim([0, 701])

# Plot each array with a different color
for i in range(10):
    plt.plot(trace_array[i], color=colors[i])
